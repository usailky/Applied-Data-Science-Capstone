# %%
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
import plotly.express as px


spacex_df = pd.read_csv("spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()


app = dash.Dash(__name__)
server = app.server

uniquelaunchsites = spacex_df['Launch Site'].unique().tolist()
lsites = []
lsites.append({'label': 'All Sites', 'value': 'All Sites'})
for site in uniquelaunchsites:
 lsites.append({'label': site, 'value': site})



app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),




                                dcc.Dropdown(id='site_dropdown',options=lsites,placeholder='Select a Launch Site', searchable = True , value = 'All Sites'),
                                html.Br(),


                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),

                                dcc.RangeSlider(
                                    id='payload_slider',
                                    min=0,
                                    max=10000,
                                    step=1000,
                                    marks = {
                                            0: '0 kg',
                                            1000: '1000 kg',
                                            2000: '2000 kg',
                                            3000: '3000 kg',
                                            4000: '4000 kg',
                                            5000: '5000 kg',
                                            6000: '6000 kg',
                                            7000: '7000 kg',
                                            8000: '8000 kg',
                                            9000: '9000 kg',
                                            10000: '10000 kg'
                                    },

                                    value=[min_payload,max_payload]
                                ),

                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),

                                ])

@app.callback(
     Output(component_id='success-pie-chart',component_property='figure'),
     [Input(component_id='site_dropdown',component_property='value')]
)
def update_graph(site_dropdown):
    if (site_dropdown == 'All Sites'):
        df  = spacex_df[spacex_df['class'] == 1]
        fig = px.pie(df, names = 'Launch Site',hole=.3,title = 'Total Success Launches By all sites')
    else:
        df  = spacex_df.loc[spacex_df['Launch Site'] == site_dropdown]
        fig = px.pie(df, names = 'class',hole=.3,title = 'Total Success Launches for site '+site_dropdown)
    return fig

@app.callback(
     Output(component_id='success-payload-scatter-chart',component_property='figure'),
     [Input(component_id='site_dropdown',component_property='value'),Input(component_id="payload_slider", component_property="value")]
)
def update_scattergraph(site_dropdown,payload_slider):
    if site_dropdown == 'All Sites':
        low, high = payload_slider
        df  = spacex_df
        mask = (df['Payload Mass (kg)'] > low) & (df['Payload Mass (kg)'] < high)
        fig = px.scatter(
            df[mask], x="Payload Mass (kg)", y="class",
            color="Booster Version",
            size='Payload Mass (kg)',
            hover_data=['Payload Mass (kg)'])
    else:
        low, high = payload_slider
        df  = spacex_df.loc[spacex_df['Launch Site'] == site_dropdown]
        mask = (df['Payload Mass (kg)'] > low) & (df['Payload Mass (kg)'] < high)
        fig = px.scatter(
            df[mask], x="Payload Mass (kg)", y="class",
            color="Booster Version",
            size='Payload Mass (kg)',
            hover_data=['Payload Mass (kg)'])
    return fig



if __name__ == '__main__':
    app.run_server(debug=False)
# Out:
# /var/folders/7w/6yqsyfk52qdbn9st_zkt2y8c0000gn/T/ipykernel_12655/1834616075.py:3: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html
# /var/folders/7w/6yqsyfk52qdbn9st_zkt2y8c0000gn/T/ipykernel_12655/1834616075.py:4: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [02/Nov/2021 01:58:05] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Nov/2021 01:58:05] "GET /_dash-component-suites/dash/deps/polyfill@7.v2_0_0m1635492942.12.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Nov/2021 01:58:05] "GET /_dash-component-suites/dash/deps/react@16.v2_0_0m1635492942.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Nov/2021 01:58:05] "GET /_dash-component-suites/dash/deps/react-dom@16.v2_0_0m1635492942.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Nov/2021 01:58:05] "GET /_dash-component-suites/dash/dash-renderer/build/dash_renderer.v2_0_0m1635492942.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Nov/2021 01:58:05] "GET /_dash-component-suites/dash/dcc/dash_core_components.v2_0_0m1635492942.js HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Nov/2021 01:58:05] "GET /_dash-component-suites/dash/html/dash_html_components.v2_0_0m1635492942.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Nov/2021 01:58:05] "GET /_dash-component-suites/dash/dash_table/bundle.v5_0_0m1635492942.js HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Nov/2021 01:58:05] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Nov/2021 01:58:05] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Nov/2021 01:58:05] "GET /_favicon.ico?v=2.0.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Nov/2021 01:58:05] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Nov/2021 01:58:05] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Nov/2021 01:58:05] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Nov/2021 01:58:05] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/flask/app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/flask/app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/flask/app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/flask/app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/dash/dash.py", line 1336, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/var/folders/7w/6yqsyfk52qdbn9st_zkt2y8c0000gn/T/ipykernel_12655/1834616075.py", line 74, in update_graph
#     fig = px.pie(df, names = 'Launch Site',hole=.3,title = 'Total Success Launches By all sites')
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 1458, in pie
#     return make_figure(
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/plotly/express/_core.py", line 1931, in make_figure
#     apply_default_cascade(args)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/plotly/express/_core.py", line 937, in apply_default_cascade
#     if args["color_discrete_sequence"] is None and args["template"].layout.colorway:
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/plotly/graph_objs/_layout.py", line 950, in colorway
#     return self["colorway"]
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/plotly/basedatatypes.py", line 5792, in __getitem__
#     return super(BaseLayoutHierarchyType, self).__getitem__(prop)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/plotly/basedatatypes.py", line 4668, in __getitem__
#     validator = self._get_validator(prop)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/plotly/basedatatypes.py", line 4289, in _get_validator
#     return ValidatorCache.get_validator(self._path_str, prop)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/plotly/validator_cache.py", line 20, in get_validator
#     from .graph_objects import Layout
# ImportError: cannot import name 'Layout' from partially initialized module 'plotly.graph_objects' (most likely due to a circular import) (/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/plotly/graph_objects/__init__.py)
# 127.0.0.1 - - [02/Nov/2021 01:58:05] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [02/Nov/2021 01:58:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Nov/2021 01:58:17] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Nov/2021 01:58:17] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Nov/2021 01:58:17] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Nov/2021 01:58:17] "GET /_favicon.ico?v=2.0.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Nov/2021 01:58:17] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Nov/2021 01:58:17] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Nov/2021 01:58:17] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Nov/2021 01:58:17] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Nov/2021 01:58:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Nov/2021 01:58:17] "POST /_dash-update-component HTTP/1.1" 200 -
